# %% [markdown]
# # Day 3 – Environment Setup
#
# This notebook confirms that my Python and Jupyter environment
# are set up correctly.

# %%
print("Environment is ready!")
# Out:
# Environment is ready!
